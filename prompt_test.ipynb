# %%
import os, json, base64, glob
from pathlib import Path
from openai import OpenAI
from moderation_agent import ModerationAgent
from PIL import Image
from image_utils import maybe_downscale

# %%
MODEL_VISION_AGENT = "gpt-4o"

with open("credentials.txt", "rb") as f:
    open_ai_key = f.readline().decode('ascii')

client = OpenAI(api_key=open_ai_key)

# %%
# def b64_image(path):
#     with open(path, "rb") as f:
#         return "data:image/" + Path(path).suffix[1:].lower() + ";base64," + base64.b64encode(f.read()).decode("utf-8")

# %%
image_paths = glob.glob("C:\\Users\\benja\\Desktop\\prompt_updates\\images\\*.png")
# image_paths = [p for p in image_paths if "jesus" in p or "clown" in p or "drinking" in p or "sexy" in p]
image_paths
# Out:
# ['C:\\Users\\benja\\Desktop\\prompt_updates\\images\\ah.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\ah_mii.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\call_me_naked_alien.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\captain_beer_mcdonalds.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\cultural_appropriation_clown.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\cultural_appropriation_clown_2.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\disney_underwear.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\drinking_godess.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\ducky_jesus.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\dumpster.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\elon.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\fat_losers.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\fight_night.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\hail_satan.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\hate_shield.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\hate_shield_2.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\Jefferson_high.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\Join_the_resistence.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\marlboro_bong.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\naked_man.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\naked_woman.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\one_gun_lingerie.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\sexy_buddah.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\smoking_mickey.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\sonic.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\tow_guns_lingerie.png',
#  'C:\\Users\\benja\\Desktop\\prompt_updates\\images\\yang.png']

# %%
# image_dict = {os.path.basename(path).split(".")[0]: b64_image(path) for path in image_paths}

# %%
def load_image(path: Path):
    image = Image.open(path)
    image = maybe_downscale(image, 500)
    buf = io.BytesIO()
    image.save(buf, format="PNG")
    img_b64 = base64.b64encode(buf.getvalue()).decode("utf-8")
    return img_b64

# %%
image_dict = {os.path.basename(p).split('.')[0]: load_image(p) for p in image_paths}

# %%
def read_definitions(dir_path:str):
    with open(f"{dir_path}/few_shot_examples.txt", 'rb') as few_shot_file:
        _few_shot_examples = few_shot_file.read().decode('utf-8')

    with open(f"{dir_path}/moderation_taxonomy.json", 'rb') as taxonomy_file:
        _moderation_taxonomy = json.load(taxonomy_file)
        _moderation_taxonomy = json.dumps(_moderation_taxonomy, ensure_ascii=False)

    with open(f"{dir_path}/system_spine.txt", 'rb') as system_spine_file:
        _system_spine = system_spine_file.read().decode('utf-8')

    with open(f"{dir_path}/user_prompt.txt", "rb") as user_prompt_file:
        _user_prompt = user_prompt_file.read().decode('utf-8').strip()

    return _system_spine, _user_prompt, _moderation_taxonomy, _few_shot_examples

# %%
system_spine, user_prompt, moderation_taxonomy, few_shot_examples = read_definitions("definitions_v0")

# %%
agent_0 = ModerationAgent(
    client=client,
    vision_model=MODEL_VISION_AGENT,
    system_spine=system_spine,
    few_shot_examples=few_shot_examples,
    moderation_taxonomy=moderation_taxonomy,
    user_prompt=user_prompt
)

# %%
taxonomy_results_0 = agent_0.moderate_images(image_dict)

# %%
taxonomy_results_0
# Out:
# {'ah_mii': {'taxonomy_version': '3.0',
#   'summary': 'Model resembles a historical figure associated with hate and extremism.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.1',
#     'rationale': 'Model resembles a historical figure known for extremism and hate.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'hail_satan': {'taxonomy_version': '3.0',
#   'summary': 'Model depicts occult/supernatural themes.',
#   'flags': [{'category_id': 'T8',
#     'subcategory_id': 'T8.1',
#     'rationale': 'Presence of pentagram and ritualistic setting indicating occult/supernatural horror.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'hate_shield_2': {'taxonomy_version': '3.0',
#   'summary': 'Shield with extremist symbol.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.2',
#     'rationale': 'Extremist propaganda symbol embedded in shield design.',
#     'evidence': {'type': 'texture', 'pointer': 'center of shield'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'disney_underwear': {'taxonomy_version': '3.0',
#   'summary': 'The model is wearing suggestive attire.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'The model is dressed in revealing and suggestive attire.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'ah': {'taxonomy_version': '3.0',
#   'summary': 'Model resembles a historical figure associated with hate and extremism.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.1',
#     'rationale': 'Model resembles a historical figure known for extremism and hate.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'hate_shield': {'taxonomy_version': '3.0',
#   'summary': 'Shield with extremist symbol.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.2',
#     'rationale': 'Extremist propaganda symbol embedded in shield design.',
#     'evidence': {'type': 'texture', 'pointer': 'shield surface'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'naked_man': {'taxonomy_version': '3.0',
#   'summary': 'Nudity and inappropriate content present.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model depicts full nudity.',
#     'evidence': {'type': 'geometry', 'pointer': 'entire model'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'fight_night': {'taxonomy_version': '3.0',
#   'summary': 'Depiction of animal cruelty and promotion of dog fighting.',
#   'flags': [{'category_id': 'T8',
#     'subcategory_id': 'T8.3',
#     'rationale': "The image depicts a dog in a cage with the text 'FIGHT NIGHT', suggesting animal cruelty and dog fighting.",
#     'evidence': {'type': 'texture', 'pointer': 'front of cage'},
#     'confidence': 0.95}],
#   'text_fragments': [{'text': 'FIGHT NIGHT',
#     'pointer': 'front of cage',
#     'language': 'en'}]},
#  'drinking_godess': {'taxonomy_version': '3.0',
#   'summary': 'Religious figure holding a beer bottle.',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.2',
#     'rationale': 'Religious figure depicted holding an alcoholic beverage.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'naked_woman': {'taxonomy_version': '3.0',
#   'summary': 'Nudity present in the 3D model.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model displays full nudity.',
#     'evidence': {'type': 'geometry', 'pointer': 'entire model'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'sonic': {'taxonomy_version': '3.0',
#   'summary': 'No issues present.',
#   'flags': [],
#   'text_fragments': []},
#  'cultural_appropriation_clown_2': {'taxonomy_version': '3.0',
#   'summary': 'Cultural appropriation and ethnic/cultural caricature',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.1',
#     'rationale': 'Recognizable ceremonial regalia elements used as costume.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'Jefferson_high': {'taxonomy_version': '3.0',
#   'summary': 'Map on a chalkboard with school-related text.',
#   'flags': [],
#   'text_fragments': [{'text': 'Jefstrom Fewnan & School',
#     'pointer': 'view#1 / bbox#1',
#     'language': 'en'},
#    {'text': 'School Law Library',
#     'pointer': 'view#1 / bbox#2',
#     'language': 'en'},
#    {'text': 'Jefferson', 'pointer': 'view#1 / bbox#3', 'language': 'en'},
#    {'text': 'Leferson', 'pointer': 'view#1 / bbox#4', 'language': 'en'},
#    {'text': '5th Grade School',
#     'pointer': 'view#1 / bbox#5',
#     'language': 'en'},
#    {'text': 'School Bus Schedule',
#     'pointer': 'view#1 / bbox#6',
#     'language': 'en'}]},
#  'elon': {'taxonomy_version': '3.0',
#   'summary': 'No issues present.',
#   'flags': [],
#   'text_fragments': []},
#  'marlboro_bong': {'taxonomy_version': '3.0',
#   'summary': 'Coded drug reference and parody of a brand.',
#   'flags': [{'category_id': 'C6',
#     'subcategory_id': 'C6.7',
#     'rationale': 'Coded drug reference with cannabis imagery and parody of a cigarette brand.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': [{'text': 'MariMboro',
#     'pointer': 'view#1 / bbox',
#     'language': 'en'},
#    {'text': 'MARIBORO', 'pointer': 'view#1 / bbox', 'language': 'en'}]},
#  'ducky_jesus': {'taxonomy_version': '3.0',
#   'summary': 'Parody of a religious figure with comedic elements.',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.4',
#     'rationale': 'Recognizable religious figure depicted in a comedic scene with duck features.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'call_me_naked_alien': {'taxonomy_version': '3.0',
#   'summary': 'The image contains nudity, inappropriate text, and PII.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model is depicted with exposed breasts.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95},
#    {'category_id': 'P5',
#     'subcategory_id': 'P5.1',
#     'rationale': 'The sign includes a phone number, which is direct PII.',
#     'evidence': {'type': 'text', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': [{'text': 'CALL ME ME',
#     'pointer': 'view#1 / bbox',
#     'language': 'en'},
#    {'text': '931-328-7331', 'pointer': 'view#1 / bbox', 'language': 'en'},
#    {'text': 'CALL ME: 1134', 'pointer': 'view#1 / bbox', 'language': 'en'}]},
#  'fat_losers': {'taxonomy_version': '3.0',
#   'summary': 'Model with text containing insults.',
#   'flags': [{'category_id': 'HR12',
#     'subcategory_id': 'HR12.1',
#     'rationale': 'Non-targeted insult; ambiguous bullying; edits required.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.9}],
#   'text_fragments': [{'text': 'NO LOSERS',
#     'pointer': 'view#1 / bbox',
#     'language': 'en'},
#    {'text': 'FAIL', 'pointer': 'view#1 / bbox', 'language': 'en'},
#    {'text': 'LOSER', 'pointer': 'view#1 / bbox', 'language': 'en'}]},
#  'smoking_mickey': {'taxonomy_version': '3.0',
#   'summary': '3D model of a recognizable character holding a cigarette.',
#   'flags': [{'category_id': 'C6',
#     'subcategory_id': 'C6.1',
#     'rationale': 'Character holding a cigarette, indicating drug use.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95},
#    {'category_id': 'I9',
#     'subcategory_id': 'I9.2',
#     'rationale': 'Recognizable character resembling a well-known IP.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.95}],
#   'text_fragments': []},
#  'cultural_appropriation_clown': {'taxonomy_version': '3.0',
#   'summary': 'Ambiguous cultural referencing; identity uncertain.',
#   'flags': [{'category_id': 'CA11',
#     'subcategory_id': 'CA11.1',
#     'rationale': 'Single weak cue; identity/fidelity unclear → ambiguous fallback.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.7}],
#   'text_fragments': []},
#  'dumpster': {'taxonomy_version': '3.0',
#   'summary': 'Graffiti with violent and profane language.',
#   'flags': [{'category_id': 'B13',
#     'subcategory_id': 'B13.1',
#     'rationale': 'Direct exhortation to violence; severe harassment.',
#     'evidence': {'type': 'texture', 'pointer': 'front of dumpster'},
#     'confidence': 0.9},
#    {'category_id': 'L4',
#     'subcategory_id': 'L4.1',
#     'rationale': 'Profane language present in graffiti.',
#     'evidence': {'type': 'texture', 'pointer': 'front of dumpster'},
#     'confidence': 0.8}],
#   'text_fragments': [{'text': 'KILL',
#     'pointer': 'front of dumpster',
#     'language': 'en'},
#    {'text': 'F**K', 'pointer': 'front of dumpster', 'language': 'en'},
#    {'text': 'LIFE', 'pointer': 'front of dumpster', 'language': 'en'}]},
#  'Join_the_resistence': {'taxonomy_version': '3.0',
#   'summary': 'The image contains a billboard with text and silhouettes that may imply violence.',
#   'flags': [{'category_id': 'V2',
#     'subcategory_id': 'V2.1',
#     'rationale': "The billboard text 'JOIN THE RESISTANCE' and silhouettes of armed figures suggest a call to violence.",
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.9}],
#   'text_fragments': [{'text': 'JOIN THE RESISTANCE',
#     'pointer': 'view#1',
#     'language': 'en'}]},
#  'captain_beer_mcdonalds': {'taxonomy_version': '3.0',
#   'summary': 'Character holding a beer and wearing a parody logo.',
#   'flags': [{'category_id': 'A7',
#     'subcategory_id': 'A7.1',
#     'rationale': 'Character holding a beer mug, indicating alcohol.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.9},
#    {'category_id': 'I9',
#     'subcategory_id': 'I9.3',
#     'rationale': 'Parodic use of a recognizable fast-food logo.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.8}],
#   'text_fragments': [{'text': "McDronald's",
#     'pointer': 'view#1',
#     'language': 'en'}]},
#  'yang': {'taxonomy_version': '3.0',
#   'summary': 'Model contains nudity and suggestive elements.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model displays nudity with exposed breasts and genital area.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 1.0},
#    {'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': "The model's attire and pose are suggestive.",
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'one_gun_lingerie': {'taxonomy_version': '3.0',
#   'summary': 'Model with suggestive and violent elements.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'Model wearing erotic attire with suggestive elements.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.9},
#    {'category_id': 'S1',
#     'subcategory_id': 'S1.4',
#     'rationale': 'Model in fetish attire with latex-like material.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.9},
#    {'category_id': 'V2',
#     'subcategory_id': 'V2.1',
#     'rationale': 'Model holding a weapon, indicating potential violence.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'tow_guns_lingerie': {'taxonomy_version': '3.0',
#   'summary': 'The model features suggestive and fetish attire.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.4',
#     'rationale': 'The model is wearing fetish attire, including a latex suit.',
#     'evidence': {'type': 'texture', 'pointer': 'view#1'},
#     'confidence': 0.95},
#    {'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': "The model's pose and attire are suggestive.",
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'sexy_buddah': {'taxonomy_version': '3.0',
#   'summary': 'Cultural and suggestive elements present.',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.4',
#     'rationale': 'Parody of a religious figure in a comedic and suggestive context.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.9},
#    {'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'Suggestive attire and pose.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#1'},
#     'confidence': 0.8}],
#   'text_fragments': []}}

# %%
agent_0_mini = ModerationAgent(
    client=client,
    vision_model="gpt-4o-mini",
    system_spine=system_spine,
    few_shot_examples=few_shot_examples,
    moderation_taxonomy=moderation_taxonomy,
    user_prompt=user_prompt
)
taxonomy_results_0_mini = agent_0_mini.moderate_images(image_dict)
# Out:
# completed elon
# completed ah_mii
# completed naked_man
# completed cultural_appropriation_clown_2
# completed fat_losers
# completed Jefferson_high
# completed hate_shield
# completed hate_shield_2
# completed ah
# completed hail_satan
# completed marlboro_bong
# completed Join_the_resistence
# completed call_me_naked_alien
# completed sonic
# completed dumpster
# completed naked_woman
# completed cultural_appropriation_clown
# completed yang
# completed one_gun_lingerie
# completed sexy_buddah
# completed captain_beer_mcdonalds
# completed disney_underwear
# completed drinking_godess
# completed fight_night
# completed ducky_jesus
# completed smoking_mickey
# completed tow_guns_lingerie

# %%
taxonomy_results_0_mini
# Out:
# {'elon': {'taxonomy_version': '3.0',
#   'summary': 'No problematic content detected.',
#   'flags': [],
#   'text_fragments': []},
#  'ah_mii': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a character resembling a historical figure associated with hate and extremism.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.1',
#     'rationale': 'Representation of a historical figure known for extremist ideologies and actions.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'naked_man': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts nudity.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model is fully nude, displaying bare skin.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'cultural_appropriation_clown_2': {'taxonomy_version': '3.0',
#   'summary': 'Cultural appropriation evident in the use of traditional regalia elements.',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.1',
#     'rationale': 'Recognizable ceremonial regalia elements used as costume.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'fat_losers': {'taxonomy_version': '3.0',
#   'summary': 'The model features graffiti text that includes potentially insulting language.',
#   'flags': [{'category_id': 'HR12',
#     'subcategory_id': 'HR12.1',
#     'rationale': "The text 'NO LOSERS HERE' can be interpreted as a general insult.",
#     'evidence': {'type': 'text', 'pointer': 'view#'},
#     'confidence': 0.8}],
#   'text_fragments': [{'text': 'NO LOSERS HERE',
#     'pointer': 'view#',
#     'language': 'en'},
#    {'text': "IT'S ALL LOSE", 'pointer': 'view#', 'language': 'en'}]},
#  'Jefferson_high': {'taxonomy_version': '3.0',
#   'summary': 'No problematic content detected.',
#   'flags': [],
#   'text_fragments': []},
#  'hate_shield': {'taxonomy_version': '3.0',
#   'summary': 'The model features a shield with a recognizable extremist symbol.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.2',
#     'rationale': 'The shield displays a swastika variant, which is an extremist symbol.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'hate_shield_2': {'taxonomy_version': '3.0',
#   'summary': 'The model features a shield with a recognizable extremist symbol.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.2',
#     'rationale': 'The shield displays a swastika, a symbol associated with hate and extremism.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'ah': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a historical figure associated with hate and extremism.',
#   'flags': [{'category_id': 'HE3',
#     'subcategory_id': 'HE3.1',
#     'rationale': 'Representation of a known extremist figure.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'hail_satan': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a scene with occult themes, including a pentagram and ritualistic elements.',
#   'flags': [{'category_id': 'T8',
#     'subcategory_id': 'T8.1',
#     'rationale': 'Occult imagery present, including a pentagram and ritualistic setting.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'marlboro_bong': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a bong and a marijuana-themed packaging, indicating drug-related content.',
#   'flags': [{'category_id': 'C6',
#     'subcategory_id': 'C6.1',
#     'rationale': 'Representation of drug paraphernalia (bong) and cannabis branding.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.0}],
#   'text_fragments': [{'text': 'Marijoroo',
#     'pointer': 'view#',
#     'language': 'en'},
#    {'text': 'MARIJUANA', 'pointer': 'view#', 'language': 'en'}]},
#  'Join_the_resistence': {'taxonomy_version': '3.0',
#   'summary': 'The model contains a billboard with a message that promotes resistance, which could imply a call to action that may be interpreted as inciting rebellion or violence.',
#   'flags': [{'category_id': 'V2',
#     'subcategory_id': 'V2.6',
#     'rationale': "The phrase 'Join the Resistance' suggests a call to action that could be interpreted as promoting dangerous imitation or challenges.",
#     'evidence': {'type': 'text', 'pointer': 'view#'},
#     'confidence': 0.8}],
#   'text_fragments': [{'text': 'JOIN THE RESISTANCE',
#     'pointer': 'view#',
#     'language': 'en'}]},
#  'call_me_naked_alien': {'taxonomy_version': '3.0',
#   'summary': 'The model contains nudity and a phone number.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model is depicted with exposed breasts.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0},
#    {'category_id': 'P5',
#     'subcategory_id': 'P5.1',
#     'rationale': 'The sign held by the model contains a phone number.',
#     'evidence': {'type': 'text', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': [{'text': 'CALL ME ME 931-328-7331',
#     'pointer': 'view#',
#     'language': 'en'}]},
#  'sonic': {'taxonomy_version': '3.0',
#   'summary': 'No problematic content detected.',
#   'flags': [],
#   'text_fragments': []},
#  'dumpster': {'taxonomy_version': '3.0',
#   'summary': 'The model contains graffiti with violent and inappropriate language.',
#   'flags': [{'category_id': 'B13',
#     'subcategory_id': 'B13.1',
#     'rationale': 'Direct exhortation to violence present in graffiti.',
#     'evidence': {'type': 'text', 'pointer': 'view#'},
#     'confidence': 0.9},
#    {'category_id': 'HR12',
#     'subcategory_id': 'HR12.1',
#     'rationale': 'General insult present in graffiti.',
#     'evidence': {'type': 'text', 'pointer': 'view#'},
#     'confidence': 0.8}],
#   'text_fragments': [{'text': 'KILL', 'pointer': 'view#'},
#    {'text': 'F**K', 'pointer': 'view#'},
#    {'text': 'LIFE', 'pointer': 'view#'}]},
#  'naked_woman': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts nudity.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model is fully nude, exposing breasts and genitalia.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'cultural_appropriation_clown': {'taxonomy_version': '3.0',
#   'summary': 'The 3D model depicts a colorful clown character with no problematic elements.',
#   'flags': [],
#   'text_fragments': []},
#  'yang': {'taxonomy_version': '3.0',
#   'summary': 'The model contains nudity and is not appropriate for child-focused spaces.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.1',
#     'rationale': 'The model is nude, exposing bare chest and genital area.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 1.0}],
#   'text_fragments': []},
#  'one_gun_lingerie': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a character in fetish attire with suggestive elements.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.4',
#     'rationale': 'The character is wearing fetish attire, including a skin-tight outfit and high heels.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9},
#    {'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'The pose and attire suggest a provocative and sexualized representation.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.8}],
#   'text_fragments': []},
#  'sexy_buddah': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a character in suggestive attire, which may not be appropriate for all audiences.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'The character is depicted in revealing and suggestive clothing.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'captain_beer_mcdonalds': {'taxonomy_version': '3.0',
#   'summary': 'The model features a character holding a beer and wearing a shirt with a recognizable fast-food logo.',
#   'flags': [{'category_id': 'A7',
#     'subcategory_id': 'A7.1',
#     'rationale': 'The character is holding a beer, which is an age-restricted product.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.0},
#    {'category_id': 'I9',
#     'subcategory_id': 'I9.2',
#     'rationale': 'The shirt prominently displays a recognizable fast-food logo.',
#     'evidence': {'type': 'texture', 'pointer': 'view#'},
#     'confidence': 0.0}],
#   'text_fragments': [{'text': "McDonald's",
#     'pointer': 'view#',
#     'language': 'en'}]},
#  'disney_underwear': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a character in revealing attire, which may be considered suggestive.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'The character is depicted in a provocative pose and revealing clothing.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.0}],
#   'text_fragments': []},
#  'drinking_godess': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a sacred figure holding a beverage, which may be considered disrespectful.',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.2',
#     'rationale': 'The sacred figure is depicted holding a beverage, which can be seen as a desecration of a religious symbol.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.0}],
#   'text_fragments': []},
#  'fight_night': {'taxonomy_version': '3.0',
#   'summary': "The model depicts a dog in a cage with a sign referencing 'Fight Night', suggesting themes of violence or animal fighting.",
#   'flags': [{'category_id': 'V2',
#     'subcategory_id': 'V2.1',
#     'rationale': 'The depiction of a dog in a cage with a reference to fighting implies themes of violence.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9}],
#   'text_fragments': [{'text': 'FIGHT NIGHT',
#     'pointer': 'view#',
#     'language': 'en'}]},
#  'ducky_jesus': {'taxonomy_version': '3.0',
#   'summary': 'The image features a cartoonish representation of a religious figure with rubber ducks, which may imply a humorous or satirical context.',
#   'flags': [{'category_id': 'CR10',
#     'subcategory_id': 'CR10.4',
#     'rationale': 'The depiction of a recognizable religious figure in a comedic scene suggests satire or parody.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.8}],
#   'text_fragments': []},
#  'smoking_mickey': {'taxonomy_version': '3.0',
#   'summary': 'The model depicts a character resembling a well-known cartoon figure holding a smoking object, which raises concerns.',
#   'flags': [{'category_id': 'C6',
#     'subcategory_id': 'C6.1',
#     'rationale': 'The character is depicted holding a smoking object, suggesting drug use.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9}],
#   'text_fragments': []},
#  'tow_guns_lingerie': {'taxonomy_version': '3.0',
#   'summary': 'The model features suggestive attire and poses.',
#   'flags': [{'category_id': 'S1',
#     'subcategory_id': 'S1.3',
#     'rationale': 'The model is depicted in a provocative pose and wearing revealing attire.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.9},
#    {'category_id': 'S1',
#     'subcategory_id': 'S1.4',
#     'rationale': 'The outfit resembles fetish attire with its skin-tight and revealing design.',
#     'evidence': {'type': 'geometry', 'pointer': 'view#'},
#     'confidence': 0.8}],
#   'text_fragments': []}}
